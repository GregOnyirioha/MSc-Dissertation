# %%
f=pd.read_csv('complete dataset.csv')
EDA=f.describe()
EDA
# Out:
#        Total Population  Land Area: Kilometers Square  \
# count      2.090000e+02                    209.000000
# mean       1.743205e+05                    355.201770
# std        1.272367e+05                    364.825254
# min        5.139400e+04                     15.540000
# 25%        1.002650e+05                     77.700000
# 50%        1.310840e+05                    212.380000
# 75%        2.088710e+05                    564.620000
# max        1.140525e+06                   1758.610000
#
#        Population Density (People per sq. km)  GDP per Capita  \
# count                              209.000000      209.000000
# mean                              1880.344498    28979.071770
# std                               2804.404180    13737.319808
# min                                 37.000000    14906.000000
# 25%                                229.000000    21098.000000
# 50%                                728.000000    25828.000000
# ...

# %%
EDA.to_csv('moreEDA.csv')
